# %% [markdown]
# # PrimeKG-GraphRAG: Biomedical Question Answering Interface
#
# This notebook provides a production-ready interface to the Graph-based Retrieval-Augmented Generation (GraphRAG) system integrated with PrimeKG for biomedical question answering.
#
# ## System Overview
#
# The GraphRAG system implements a four-stage pipeline:
# 1. **Query Processing**: Extracts entities and identifies query intent
# 2. **Graph Retrieval**: Agent-based exploration of PrimeKG knowledge graph
# 3. **Context Organization**: Structures retrieved information hierarchically
# 4. **Response Generation**: Generates comprehensive answers using LLM
#
# ## Key Features
#
# - **Multi-hop reasoning** for complex biomedical relationships
# - **Entity type inference**
# - **Comprehensive error handling**

# %%
# Import required libraries
import sys
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# Add project root to path
project_root = Path().resolve().parent
sys.path.insert(0, str(project_root))

# Import GraphRAG system
from src import GraphRAG, GraphRAGConfig

print("✓ Imports successful")
# Out:
# ✓ Imports successful

# %% [markdown]
# ## System Initialization
#
# Initialize the GraphRAG system. This loads the PrimeKG knowledge graph and sets up all pipeline components.
#
# **Note**: First-time initialization may take several minutes to load and cache the PrimeKG data.

# %%
# Initialize GraphRAG system
# Configuration will be loaded from environment variables or use defaults
config = GraphRAGConfig()
graphrag = GraphRAG(config)

# Initialize all components (loads PrimeKG data)
print("Initializing GraphRAG system...")
if graphrag.initialize():
    print("✓ GraphRAG system initialized successfully!")
    
    # Display system statistics
    stats = graphrag.data_source.get_graph_statistics()
    print(f"\nPrimeKG Graph Statistics:")
    print(f"  - Total nodes: {stats.get('total_nodes', 0):,}")
    print(f"  - Total edges: {stats.get('total_edges', 0):,}")
    print(f"  - Entity types: {len(stats.get('entity_types', {}))}")
else:
    print(f"✗ Initialization failed: {graphrag.initialization_error}")
    raise RuntimeError("Failed to initialize GraphRAG system")
# Out:
# 2025-11-12 22:22:36,594 - src - INFO - GraphRAG initialized with config: data
# Initializing GraphRAG system...
# 2025-11-12 22:22:36,641 - src - INFO - Initializing GraphRAG system...
# 2025-11-12 22:22:36,642 - src - INFO - Initializing PrimeKG data source...
# 2025-11-12 22:22:36,644 - src.graph_data_source - INFO - Initialized PrimeKG data source with data_dir: data
# 2025-11-12 22:22:36,646 - src.graph_data_source - INFO - Cache enabled: True
# 2025-11-12 22:22:36,648 - src.graph_data_source - INFO - Auto-download enabled: True
# 2025-11-12 22:22:36,649 - src.graph_data_source - INFO - Neo4j connection info found in environment. Will attempt to connect on load().
# 2025-11-12 22:22:40,748 - src.graph_data_source - WARNING - Neo4j connection failed, falling back to PyKEEN: Couldn't connect to localhost:7687 (resolved to ('[::1]:7687', '127.0.0.1:7687')):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [WinError 10061] No connection could be made because the target machine actively refused it)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [WinError 10061] No connection could be made because the target machine actively refused it)
# 2025-11-12 22:23:03,397 - src.graph_data_source - INFO - Applying enhanced entity classification to cached data...
# 2025-11-12 22:23:03,399 - src.graph_data_source - INFO - Applying enhanced entity type classification...
# 2025-11-12 22:23:05,999 - src.graph_data_source - INFO - Enhanced entity classification complete:
# 2025-11-12 22:23:06,001 - src.graph_data_source - INFO -   Reclassified: 5 entities
# 2025-11-12 22:23:06,002 - src.graph_data_source - INFO -   Unknown entities: 14,603 -> 14,598
# 2025-11-12 22:23:06,005 - src.graph_data_source - INFO -   Unknown percentage: 11.3%
# 2025-11-12 22:23:06,007 - src.graph_data_source - INFO -   Improvement: 5 entities (0.0%)
# 2025-11-12 22:23:06,009 - src.graph_data_source - INFO - [OK] Target achieved: Unknown entities < 30%
# 2025-11-12 22:23:06,011 - src.graph_data_source - INFO - Loaded PrimeKG data from cache
# 2025-11-12 22:23:06,013 - src - INFO - Initializing query processor...
# 2025-11-12 22:23:06,014 - src.query_processor - INFO - Query processor initialized (spaCy will be loaded lazily on first use)
# 2025-11-12 22:23:06,016 - src - INFO - Initializing retriever...
# 2025-11-12 22:23:06,018 - src.llm_client - INFO - Using robust LLM client with automatic fallbacks
# 2025-11-12 22:23:06,019 - src.llm_client - INFO - Auto-selecting best available Anthropic model...
# 2025-11-12 22:23:06,733 - src.model_tester - INFO - Anthropic client initialized for model testing
# 2025-11-12 22:23:06,735 - src.model_tester - INFO - Finding best available model for use case: general_purpose
# 2025-11-12 22:23:06,736 - src.model_tester - INFO - Starting comprehensive Anthropic model testing...
# 2025-11-12 22:23:06,761 - src.model_tester - INFO - Loaded 8 cached model test results
# 2025-11-12 22:23:06,763 - src.model_tester - INFO - Testing 0 models (using 8 cached results)
# 2025-11-12 22:23:06,766 - src.model_tester - INFO - Found 1 available models
# 2025-11-12 22:23:06,767 - src.model_tester - INFO - Selected best model: claude-3-haiku-20240307 (score: 74.6)
# 2025-11-12 22:23:06,769 - src.model_tester - INFO - Model ranking:
# 2025-11-12 22:23:06,771 - src.model_tester - INFO -   [OK] claude-3-haiku-20240307: 74.6
# 2025-11-12 22:23:06,772 - src.llm_client - INFO - Auto-selected model: claude-3-haiku-20240307
# 2025-11-12 22:23:07,481 - src.llm_client - INFO - Initialized Anthropic client with model: claude-3-haiku-20240307
# 2025-11-12 22:23:07,485 - src.llm_client - INFO - Added Anthropic client with auto-selected model: claude-3-haiku-20240307
# 2025-11-12 22:23:07,487 - src.llm_client - INFO - Added Mock client as final fallback
# 2025-11-12 22:23:07,488 - src.llm_client - INFO - Initialized robust client with 2 fallback options
# 2025-11-12 22:23:07,489 - src.retriever - INFO - LLM client initialized: RobustLLMClient
# 2025-11-12 22:23:07,491 - src.retriever - INFO - Agent-based retriever initialized
# 2025-11-12 22:23:07,492 - src - INFO - Initializing organizer...
# 2025-11-12 22:23:07,612 - src.organizer - INFO - PrimeKG Organizer initialized
# 2025-11-12 22:23:07,614 - src - INFO - Initializing generator...
# 2025-11-12 22:23:07,616 - src.llm_client - INFO - Using robust LLM client with automatic fallbacks
# 2025-11-12 22:23:07,617 - src.llm_client - INFO - Auto-selecting best available Anthropic model...
# 2025-11-12 22:23:08,424 - src.model_tester - INFO - Anthropic client initialized for model testing
# 2025-11-12 22:23:08,426 - src.model_tester - INFO - Finding best available model for use case: general_purpose
# 2025-11-12 22:23:08,427 - src.model_tester - INFO - Starting comprehensive Anthropic model testing...
# 2025-11-12 22:23:08,433 - src.model_tester - INFO - Loaded 8 cached model test results
# 2025-11-12 22:23:08,434 - src.model_tester - INFO - Testing 0 models (using 8 cached results)
# 2025-11-12 22:23:08,437 - src.model_tester - INFO - Found 1 available models
# 2025-11-12 22:23:08,439 - src.model_tester - INFO - Selected best model: claude-3-haiku-20240307 (score: 74.6)
# 2025-11-12 22:23:08,440 - src.model_tester - INFO - Model ranking:
# 2025-11-12 22:23:08,441 - src.model_tester - INFO -   [OK] claude-3-haiku-20240307: 74.6
# 2025-11-12 22:23:08,442 - src.llm_client - INFO - Auto-selected model: claude-3-haiku-20240307
# 2025-11-12 22:23:09,168 - src.llm_client - INFO - Initialized Anthropic client with model: claude-3-haiku-20240307
# 2025-11-12 22:23:09,171 - src.llm_client - INFO - Added Anthropic client with auto-selected model: claude-3-haiku-20240307
# 2025-11-12 22:23:09,172 - src.llm_client - INFO - Added Mock client as final fallback
# 2025-11-12 22:23:09,174 - src.llm_client - INFO - Initialized robust client with 2 fallback options
# 2025-11-12 22:23:09,176 - src.generator - INFO - LLM client initialized for generation: RobustLLMClient
# 2025-11-12 22:23:09,177 - src.generator - INFO - PrimeKG Generator initialized with LLM client
# 2025-11-12 22:23:09,178 - src - INFO - GraphRAG system initialized successfully
# ✓ GraphRAG system initialized successfully!
#
# PrimeKG Graph Statistics:
#   - Total nodes: 129,262
#   - Total edges: 6,479,992
#   - Entity types: 0

# %% [markdown]
# ## Query Processing
#
# Process biomedical questions through the GraphRAG pipeline. The system supports various query types:
#
# - **Treatment queries**: "How does metformin work to treat type 2 diabetes?"
# - **Mechanism queries**: "Explain the insulin signaling pathway"
# - **Side effect queries**: "What are the side effects of aspirin?"
# - **Relationship queries**: "What genes are associated with Alzheimer's disease?"
# - **Pathway queries**: "What is the role of BRCA1 in breast cancer development?"

# %%
def process_query(question: str, verbose: bool = True):
    """
    Process a biomedical question through the GraphRAG pipeline.
    
    Args:
        question: Natural language biomedical question
        verbose: Whether to display detailed information
        
    Returns:
        GraphRAGResult object with query results
    """
    print(f"\n{'='*80}")
    print(f"Query: {question}")
    print(f"{'='*80}\n")
    
    # Process query
    result = graphrag.query(question)
    
    if verbose:
        # Display processing information
        # Access nested attributes correctly
        print(f"Query Type: {result.processed_query.query_type}")
        print(f"Processing Time: {result.processing_time:.2f}s")
        print(f"\nEntities Retrieved: {len(result.retrieval_result.entities)}")
        print(f"Relationships Retrieved: {len(result.retrieval_result.relationships)}")
        print(f"Confidence Score: {result.overall_confidence:.2%}")
        
        # Display key entities
        if result.retrieval_result.entities:
            print(f"\nKey Entities ({min(5, len(result.retrieval_result.entities))} of {len(result.retrieval_result.entities)}):")
            for entity in result.retrieval_result.entities[:5]:
                print(f"  - {entity.name} ({entity.entity_type})")
        
        # Display key relationships
        if result.retrieval_result.relationships:
            print(f"\nKey Relationships ({min(5, len(result.retrieval_result.relationships))} of {len(result.retrieval_result.relationships)}):")
            for rel in result.retrieval_result.relationships[:5]:
                print(f"  - {rel.source_entity.name} --[{rel.relation_type}]--> {rel.target_entity.name}")
    
    print(f"\n{'='*80}")
    print("ANSWER:")
    print(f"{'='*80}")
    print(result.generated_response.text)
    print(f"{'='*80}\n")
    
    return result

# %% [markdown]
# ### Example Query 1: Treatment Mechanism
#
# Query about how a drug works to treat a disease.

# %%
# Example 1: Treatment mechanism query
question1 = "How does metformin work to treat type 2 diabetes?"
result1 = process_query(question1)
# Out:
# ================================================================================
# Query: How does metformin work to treat type 2 diabetes?
# ================================================================================
#
# 2025-11-12 22:23:16,355 - src.query_processor - INFO - Processing query: How does metformin work to treat type 2 diabetes?
# 2025-11-12 22:23:16,357 - src.query_processor - INFO - Identified query type: treatment_query
# 2025-11-12 22:23:16,360 - src.graph_data_source - WARNING - Memory usage (3638.6MB) exceeds cleanup threshold (3481.6MB). Triggering cleanup.
# 2025-11-12 22:23:16,362 - src.graph_data_source - INFO - Starting memory cleanup (aggressive=False). Initial usage: 3638.6MB
# 2025-11-12 22:23:20,809 - src.graph_data_source - INFO - Memory cleanup completed. Freed 0.0MB. Current usage: 3638.6MB
# 2025-11-12 22:23:20,943 - src.graph_data_source - INFO - Starting memory cleanup (aggressive=True). Initial usage: 3638.6MB
# 2025-11-12 22:23:25,394 - src.graph_data_source - INFO - Memory cleanup completed. Freed 0.0MB. Current usage: 3638.6MB
# 2025-11-12 22:23:43,837 - src.query_processor - INFO - Loaded biomedical NER model (lazy loading)
# 2025-11-12 22:23:43,902 - src.query_processor - INFO - Entity extraction found 4 entities using methods: ['pattern_match', 'pattern_match', 'pattern_match', 'ner']
# 2025-11-12 22:23:43,903 - src.query_processor - INFO - Extracted 4 entities
# 2025-11-12 22:23:43,905 - src.query_processor - INFO - Identified relations: ['drug_protein', 'drug_drug', 'exposure_disease']
# 2025-11-12 22:23:43,906 - src.retriever - INFO - Starting agent-based retrieval for query: How does metformin work to treat type 2 diabetes?
# 2025-11-12 22:23:45,780 - src.retriever - INFO - Query analysis: {'query_type': 'mechanism', 'primary_entities': ['metformin', 'type 2 diabetes'], 'relevant_relationships': ['treats', 'mechanism_of_action'], 'retrieval_strategy': 'mechanism_analysis', 'reasoning': "This query is asking about the mechanism of action of the drug metformin in treating type 2 diabetes. The primary entities are the drug metformin and the disease type 2 diabetes. The most relevant relationships are 'treats' (how metformin is used to treat type 2 diabetes) and 'mechanism_of_action' (how metformin works to produce its therapeutic effects). To answer this query, a mechanism analysis approach would be most appropriate, exploring the known mechanisms by which metformin exerts its effects on type 2 diabetes, such as its actions on glucose metabolism, insulin sensitivity, and other relevant pathways."}
# 2025-11-12 22:23:45,782 - src.query_processor - INFO - Processing query: How does metformin work to treat type 2 diabetes?
# 2025-11-12 22:23:45,783 - src.query_processor - INFO - Identified query type: treatment_query
# 2025-11-12 22:23:45,935 - src.query_processor - INFO - Entity extraction found 4 entities using methods: ['pattern_match', 'pattern_match', 'pattern_match', 'ner']
# 2025-11-12 22:23:45,938 - src.query_processor - INFO - Extracted 4 entities
# 2025-11-12 22:23:45,940 - src.query_processor - INFO - Identified relations: ['drug_protein', 'drug_drug', 'exposure_disease']
# 2025-11-12 22:23:46,009 - src.graph_data_source - WARNING - Type filtering removed ALL 4812 entities. Requested types: ['Pathway']. Attempting type re-inference...
# 2025-11-12 22:23:46,990 - src.graph_data_source - WARNING - Type re-inference failed. Sample types: {'protein', 'drug', 'disease'}. Returning unfiltered results.
# 2025-11-12 22:23:46,993 - src.retriever - INFO - Identified 7 seed entities
# 2025-11-12 22:23:47,006 - src.retriever - INFO - Added seed entity: Metformin (type: drug)
# 2025-11-12 22:23:47,009 - src.retriever - INFO - Added seed entity: maturity-onset diabetes of the young (type: disease)
# 2025-11-12 22:23:47,015 - src.retriever - INFO - Added seed entity: type 2 diabetes mellitus (type: disease)
# 2025-11-12 22:23:47,053 - src.retriever - INFO - Added seed entity: treatment-refractory schizophrenia (type: disease)
# 2025-11-12 22:23:47,055 - src.retriever - INFO - Added seed entity: acute myeloid leukemia and myelodysplastic syndromes related to topoisomerase type 2 inhibitor (type: disease)
# 2025-11-12 22:23:47,057 - src.retriever - INFO - Added seed entity: Type 1 and type 2 muscle fiber minicore regions (type: disease)
# 2025-11-12 22:23:47,058 - src.retriever - INFO - Added seed entity: Type 1 fibers relatively smaller than type 2 fibers (type: phenotype)
# 2025-11-12 22:23:47,060 - src.graph_data_source - WARNING - Memory usage (5261.9MB) exceeds cleanup threshold (3481.6MB). Triggering cleanup.
# 2025-11-12 22:23:47,061 - src.graph_data_source - INFO - Starting memory cleanup (aggressive=False). Initial usage: 5261.9MB
# 2025-11-12 22:23:53,350 - src.graph_data_source - INFO - Memory cleanup completed. Freed 0.0MB. Current usage: 5261.9MB
# 2025-11-12 22:23:53,356 - src.retriever - INFO - Batch analyzing 3 borderline entities
# 2025-11-12 22:23:53,359 - src.retriever - WARNING - Batch analysis failed, falling back to sequential: Cannot run the event loop while another loop is running
# 2025-11-12 22:23:53,361 - src.retriever - INFO - Exploring entity: diabetes mellitus (disease)
# 2025-11-12 22:23:53,363 - src.retriever - INFO - Using LLM for borderline entity: diabetes mellitus (disease)
# 2025-11-12 22:23:55,276 - src.retriever - INFO - Added relevant entity: diabetes mellitus (disease) (type: disease, score: 0.80)
# 2025-11-12 22:23:55,277 - src.retriever - INFO - Exploring entity: congenital fiber-type disproportion myopathy
# 2025-11-12 22:23:55,278 - src.retriever - INFO - Using LLM for borderline entity: congenital fiber-type disproportion myopathy
# 2025-11-12 22:23:56,671 - src.retriever - INFO - Exploring entity: myopathy, congenital, with fiber-type disproportion, X-linked
# 2025-11-12 22:23:56,673 - src.retriever - INFO - Using LLM for borderline entity: myopathy, congenital, with fiber-type disproportion, X-linked
# 2025-11-12 22:23:58,388 - src.retriever - INFO - Exploring entity: Abnormality of skeletal muscle fiber size
# 2025-11-12 22:23:58,421 - src.retriever - INFO - Exploring entity: Bailey-Bloch congenital myopathy
# 2025-11-12 22:23:58,455 - src.retriever - INFO - Exploring entity: Abnormal muscle fiber morphology
# 2025-11-12 22:23:58,491 - src.retriever - INFO - Exploring entity: familial partial lipodystrophy
# 2025-11-12 22:23:58,528 - src.retriever - INFO - Exploring entity: Increased variability in muscle fiber diameter
# 2025-11-12 22:23:58,566 - src.retriever - INFO - Exploring entity: congenital myopathy
# 2025-11-12 22:23:58,607 - src.retriever - INFO - Exploring entity: hyaline body myopathy
# 2025-11-12 22:23:58,648 - src.retriever - INFO - Exploring entity: nemaline myopathy
# 2025-11-12 22:24:00,783 - src.retriever - WARNING - Type filter too strict for entity 'maturity-onset diabetes of the young' (types: ['drug_drug', 'drug_protein', 'exposure_disease']), trying without filter
# 2025-11-12 22:24:00,784 - src.retriever - WARNING - Unfiltered query returned 43 neighbors, scoring and filtering by relevance
# 2025-11-12 22:24:00,786 - src.retriever - INFO - Filtered to top 20 neighbors by relevance (scores: ['0.60', '0.60', '0.60', '0.60', '0.60', '0.30', '0.30', '0.30', '0.27', '0.27', '0.27', '0.27', '0.27', '0.27', '0.27', '0.27', '0.27', '0.27', '0.27', '0.27'])
# 2025-11-12 22:24:00,801 - src.retriever - WARNING - Type filter too strict for entity 'treatment-refractory schizophrenia' (types: ['drug_drug', 'drug_protein', 'exposure_disease']), trying without filter
# 2025-11-12 22:24:00,802 - src.retriever - WARNING - No neighbors passed relevance filter (threshold: 0.2) for entity 'treatment-refractory schizophrenia'
# 2025-11-12 22:24:00,803 - src.retriever - WARNING - Type filter too strict for entity 'acute myeloid leukemia and myelodysplastic syndromes related to topoisomerase type 2 inhibitor' (types: ['drug_drug', 'drug_protein', 'exposure_disease']), trying without filter
# 2025-11-12 22:24:00,805 - src.retriever - WARNING - Unfiltered query returned 156 neighbors, scoring and filtering by relevance
# 2025-11-12 22:24:00,810 - src.retriever - INFO - Filtered to top 20 neighbors by relevance (scores: ['0.30', '0.30', '0.30', '0.30', '0.30', '0.30', '0.30', '0.30', '0.30', '0.30', '0.30', '0.30', '0.27', '0.27', '0.27', '0.27', '0.27', '0.27', '0.27', '0.27'])
# 2025-11-12 22:24:00,816 - src.retriever - INFO - Stopping relationship retrieval - reached limit (50)
# 2025-11-12 22:24:00,820 - src.retriever - INFO - Method 3.5: Checking for relationships with 2 expected targets: ['diabetes', 'type 2 diabetes']
# 2025-11-12 22:24:00,822 - src.retriever - INFO - Agent-based retrieval completed. Retrieved 30 entities, 50 relationships
# 2025-11-12 22:24:00,824 - src.organizer - INFO - Organizing retrieved context
# 2025-11-12 22:24:00,826 - src.organizer - INFO - Built hierarchical view
# 2025-11-12 22:24:01,324 - src.organizer - INFO - Created 0 pathway clusters
# 2025-11-12 22:24:01,326 - src.organizer - INFO - Created 3 entity groups
# 2025-11-12 22:24:01,333 - src.organizer - INFO - Constructed 23 evidence chains
# 2025-11-12 22:24:01,831 - src.generator - INFO - Generating response
# 2025-11-12 22:24:04,356 - src.generator - INFO - Successfully generated response using LLM API
# Query Type: treatment_query
# Processing Time: 48.00s
#
# Entities Retrieved: 30
# Relationships Retrieved: 50
# Confidence Score: 58.25%
#
# Key Entities (5 of 30):
#   - Metformin (drug)
#   - maturity-onset diabetes of the young (disease)
#   - type 2 diabetes mellitus (disease)
#   - treatment-refractory schizophrenia (disease)
#   - acute myeloid leukemia and myelodysplastic syndromes related to topoisomerase type 2 inhibitor (disease)
#
# Key Relationships (5 of 50):
#   - Metformin --[drug_drug]--> Pentostatin
#   - Metformin --[drug_drug]--> Atorvastatin
#   - Metformin --[drug_drug]--> Bucindolol
#   - Metformin --[drug_drug]--> Epitizide
#   - Metformin --[drug_drug]--> Oxacillin
#
# ================================================================================
# ANSWER:
# ================================================================================
# Metformin is a widely used medication for the treatment of type 2 diabetes, a chronic condition characterized by the body's inability to effectively use insulin, a hormone that regulates blood sugar levels.
#
# The primary mechanism by which metformin works to treat type 2 diabetes is by reducing the amount of glucose produced by the liver and increasing the sensitivity of the body's cells to insulin. Specifically, metformin activates an enzyme called AMPK (AMP-activated protein kinase), which acts as a cellular energy sensor. When AMPK is activated, it inhibits the production of glucose by the liver, reducing the overall amount of glucose in the bloodstream. Additionally, metformin enhances the sensitivity of the body's cells to insulin, allowing them to more effectively utilize the available glucose.
#
# This dual mechanism of action - reducing glucose production and increasing insulin sensitivity - helps to lower and stabilize blood sugar levels in individuals with type 2 diabetes. The relationships between metformin and other drugs, such as pentostatin and atorvastatin, as well as the connections between type 2 diabetes and related conditions like maturity-onset diabetes of the young, provide further context for understanding the broader implications of metformin's use in the management of this complex metabolic disorder.
# ================================================================================

# %% [markdown]
# ### Example Query 2: Gene-Disease Association
#
# Query about genetic associations with diseases.

# %%
# Example 2: Side effect query
question2 = "What genes are associated with Alzheimer's disease?"
result2 = process_query(question2)
# Out:
# ================================================================================
# Query: What genes are associated with Alzheimer's disease?
# ================================================================================
#
# 2025-11-12 22:24:04,376 - src.query_processor - INFO - Processing query: What genes are associated with Alzheimer's disease?
# 2025-11-12 22:24:04,378 - src.query_processor - INFO - Identified query type: relationship_query
# 2025-11-12 22:24:04,735 - src.query_processor - INFO - Entity extraction found 6 entities using methods: ['pattern_match', 'pattern_match', 'ner', 'ner', 'ner', 'token_search']
# 2025-11-12 22:24:04,736 - src.query_processor - INFO - Extracted 6 entities
# 2025-11-12 22:24:04,738 - src.query_processor - INFO - Identified relations: ['disease_disease', 'disease_protein', 'protein_protein']
# 2025-11-12 22:24:04,739 - src.retriever - INFO - Starting agent-based retrieval for query: What genes are associated with Alzheimer's disease?
# 2025-11-12 22:24:06,254 - src.retriever - INFO - Query analysis: {'query_type': 'gene_disease', 'primary_entities': ['genes', "Alzheimer's disease"], 'relevant_relationships': ['associated with', 'linked to', 'involved in'], 'retrieval_strategy': 'exploration', 'reasoning': "This query is asking about the genes associated with Alzheimer's disease, which is a type of gene-disease relationship query. The primary entities to explore are genes and Alzheimer's disease. The relevant relationships are those that link genes to the disease, such as 'associated with', 'linked to', and 'involved in'. To answer this query, an exploration-based retrieval strategy would be appropriate, where we search for known associations between genes and Alzheimer's disease in biomedical knowledge graphs and databases."}
# 2025-11-12 22:24:06,255 - src.query_processor - INFO - Processing query: What genes are associated with Alzheimer's disease?
# 2025-11-12 22:24:06,257 - src.query_processor - INFO - Identified query type: relationship_query
# 2025-11-12 22:24:06,271 - src.query_processor - INFO - Entity extraction found 6 entities using methods: ['pattern_match', 'pattern_match', 'ner', 'ner', 'ner', 'token_search']
# 2025-11-12 22:24:06,272 - src.query_processor - INFO - Extracted 6 entities
# 2025-11-12 22:24:06,274 - src.query_processor - INFO - Identified relations: ['disease_disease', 'disease_protein', 'protein_protein']
# 2025-11-12 22:24:06,276 - src.retriever - INFO - Identified 6 seed entities
# 2025-11-12 22:24:06,279 - src.retriever - INFO - Added seed entity: Alzheimer disease (type: disease)
# 2025-11-12 22:24:06,317 - src.retriever - INFO - Added seed entity: secondary interstitial lung disease specific to childhood associated with a granulomatous disease (type: disease)
# 2025-11-12 22:24:06,319 - src.retriever - INFO - Added seed entity: TP53 Regulates Metabolic Genes (type: pathway)
# 2025-11-12 22:24:06,336 - src.retriever - INFO - Added seed entity: polyneuropathy associated with IgM monoclonal gammapathy with anti-MAG (type: disease)
# 2025-11-12 22:24:06,338 - src.retriever - INFO - Added seed entity: Deregulated CDK5 triggers multiple neurodegenerative pathways in Alzheimer's disease models (type: disease)
# 2025-11-12 22:24:06,365 - src.retriever - INFO - Added seed entity: lymphoproliferative disease associated with primary immune disease (type: disease)
# 2025-11-12 22:24:06,368 - src.retriever - INFO - Batch analyzing 4 borderline entities
# 2025-11-12 22:24:06,372 - src.retriever - WARNING - Batch analysis failed, falling back to sequential: Cannot run the event loop while another loop is running
# 2025-11-12 22:24:06,373 - src.retriever - INFO - Exploring entity: Dementia
# 2025-11-12 22:24:06,374 - src.retriever - INFO - Using LLM for borderline entity: Dementia
# 2025-11-12 22:24:08,485 - src.retriever - INFO - Added relevant entity: Dementia (type: protein, score: 0.70)
# 2025-11-12 22:24:08,487 - src.retriever - INFO - Exploring entity: inflammatory demyelinating polyradiculoneuropathy
# 2025-11-12 22:24:08,489 - src.retriever - INFO - Using LLM for borderline entity: inflammatory demyelinating polyradiculoneuropathy
# 2025-11-12 22:24:09,763 - src.retriever - INFO - Exploring entity: Neurodegenerative Diseases
# 2025-11-12 22:24:09,764 - src.retriever - INFO - Using LLM for borderline entity: Neurodegenerative Diseases
# 2025-11-12 22:24:11,604 - src.retriever - INFO - Added relevant entity: Neurodegenerative Diseases (type: disease, score: 0.80)
# 2025-11-12 22:24:11,606 - src.retriever - INFO - Exploring entity: immunodeficiency-associated lymphoproliferative disease
# 2025-11-12 22:24:11,608 - src.retriever - INFO - Using LLM for borderline entity: immunodeficiency-associated lymphoproliferative disease
# 2025-11-12 22:24:12,782 - src.retriever - INFO - Exploring entity: CDK5
# 2025-11-12 22:24:12,790 - src.retriever - INFO - Exploring entity: CAPN1
# 2025-11-12 22:24:12,800 - src.retriever - INFO - Exploring entity: FASLG
# 2025-11-12 22:24:12,813 - src.retriever - INFO - Exploring entity: LMNA
# 2025-11-12 22:24:12,838 - src.retriever - INFO - Exploring entity: CDC25A
# 2025-11-12 22:24:12,868 - src.retriever - INFO - Exploring entity: CAPN2
# 2025-11-12 22:24:12,895 - src.retriever - INFO - Exploring entity: YWHAE
# 2025-11-12 22:24:12,932 - src.retriever - INFO - Exploring entity: CDK5R1
# 2025-11-12 22:24:12,984 - src.retriever - INFO - Added expected target entity: APOE (type: gene, was: protein)
# 2025-11-12 22:24:13,033 - src.retriever - INFO - Added expected target entity: APP (type: gene, was: protein)
# 2025-11-12 22:24:13,076 - src.retriever - INFO - Added expected target entity: PSEN1 (type: gene, was: protein)
# 2025-11-12 22:24:13,122 - src.retriever - INFO - Added expected target entity: PSEN2 (type: gene, was: protein)
# 2025-11-12 22:24:13,182 - src.retriever - WARNING - No neighbors passed relevance filter (threshold: 0.2) for entity 'secondary interstitial lung disease specific to childhood associated with a granulomatous disease'
# 2025-11-12 22:24:13,183 - src.retriever - WARNING - Type filter too strict for entity 'TP53 Regulates Metabolic Genes' (types: ['disease_protein', 'protein_protein', 'disease_disease', 'disease_phenotype_positive']), trying without filter
# 2025-11-12 22:24:13,184 - src.retriever - WARNING - Unfiltered query returned 75 neighbors, scoring and filtering by relevance
# 2025-11-12 22:24:13,189 - src.retriever - INFO - Filtered to top 20 neighbors by relevance (scores: ['0.30', '0.30', '0.30', '0.30', '0.30', '0.30', '0.30', '0.30', '0.30', '0.27', '0.27', '0.27', '0.27', '0.27', '0.27', '0.27', '0.27', '0.27', '0.27', '0.27'])
# 2025-11-12 22:24:13,205 - src.retriever - INFO - Stopping relationship retrieval - reached limit (50)
# 2025-11-12 22:24:13,208 - src.retriever - INFO - Method 3.5: Checking for relationships with 4 expected targets: ['APOE', 'APP', 'PSEN1', 'PSEN2']
# 2025-11-12 22:24:13,211 - src.retriever - INFO - Agent-based retrieval completed. Retrieved 30 entities, 50 relationships
# 2025-11-12 22:24:13,215 - src.organizer - INFO - Organizing retrieved context
# 2025-11-12 22:24:13,217 - src.organizer - INFO - Built hierarchical view
# 2025-11-12 22:24:13,724 - src.organizer - INFO - Created 2 pathway clusters
# 2025-11-12 22:24:13,725 - src.organizer - INFO - Created 6 entity groups
# 2025-11-12 22:24:13,734 - src.organizer - INFO - Constructed 128 evidence chains
# 2025-11-12 22:24:14,226 - src.generator - INFO - Generating response
# 2025-11-12 22:24:17,516 - src.generator - INFO - Successfully generated response using LLM API
# Query Type: relationship_query
# Processing Time: 13.15s
#
# Entities Retrieved: 30
# Relationships Retrieved: 50
# Confidence Score: 58.78%
#
# Key Entities (5 of 30):
#   - Alzheimer disease (disease)
#   - secondary interstitial lung disease specific to childhood associated with a granulomatous disease (disease)
#   - TP53 Regulates Metabolic Genes (pathway)
#   - polyneuropathy associated with IgM monoclonal gammapathy with anti-MAG (disease)
#   - Deregulated CDK5 triggers multiple neurodegenerative pathways in Alzheimer's disease models (disease)
#
# Key Relationships (5 of 50):
#   - Deregulated CDK5 triggers multiple neurodegenerative pathways in Alzheimer's disease models --[pathway_pathway]--> Neurodegenerative Diseases
#   - Deregulated CDK5 triggers multiple neurodegenerative pathways in Alzheimer's disease models --[pathway_protein]--> APP
#   - Dementia --[disease_phenotype_positive]--> Alzheimer disease
#   - Neurodegenerative Diseases --[pathway_pathway]--> Deregulated CDK5 triggers multiple neurodegenerative pathways in Alzheimer's disease models
#   - APOE --[protein_protein]--> PSEN1
#
# ================================================================================
# ANSWER:
# ================================================================================
# Certainly, I'd be happy to provide a detailed explanation of the genes associated with Alzheimer's disease based on the information in the knowledge graph.
#
# Alzheimer's disease is a complex neurodegenerative disorder that is influenced by multiple genetic factors. The knowledge graph highlights several key genes that have been linked to the development and progression of Alzheimer's disease:
#
# 1. APOE (Apolipoprotein E): The APOE gene is the most well-established genetic risk factor for late-onset Alzheimer's disease. Certain variants of the APOE gene, particularly the APOE ε4 allele, have been shown to increase an individual's risk of developing Alzheimer's disease. The APOE protein plays a crucial role in the transport and metabolism of cholesterol in the brain, and disruptions in this process are thought to contribute to the pathogenesis of Alzheimer's.
#
# 2. APP (Amyloid Precursor Protein): The APP gene encodes a protein that is the precursor to the amyloid-beta (Aβ) peptide, which is a key component of the amyloid plaques found in the brains of individuals with Alzheimer's disease. Mutations in the APP gene can lead to the overproduction or altered processing of Aβ, contributing to the accumulation of these toxic proteins and the development of Alzheimer's pathology.
#
# 3. PSEN1 (Presenilin 1) and PSEN2 (Presenilin 2): These genes encode components of the gamma-secretase complex, which is responsible for the cleavage of the APP protein to generate Aβ peptides. Mutations in the PSEN1 and PSEN2 genes can disrupt this process, leading to the increased production of the more amyloidogenic forms of Aβ, further contributing to the development of Alzheimer's disease.
#
# The knowledge graph also highlights the involvement of other genes, such as SOD2 (Superoxide Dismutase
# ================================================================================

# %% [markdown]
# ### Example Query 3: Pathway Explanation
#
# Query about biological pathways and mechanisms

# %%
# Example 3: Gene-disease association query
question3 = "What genes are associated with Alzheimer's disease?"
result3 = process_query(question3)
# Out:
# ================================================================================
# Query: What genes are associated with Alzheimer's disease?
# ================================================================================
#
# 2025-11-12 22:24:17,543 - src.query_processor - INFO - Processing query: What genes are associated with Alzheimer's disease?
# 2025-11-12 22:24:17,545 - src.query_processor - INFO - Identified query type: relationship_query
# 2025-11-12 22:24:17,547 - src.graph_data_source - WARNING - Memory usage (5319.7MB) exceeds cleanup threshold (3481.6MB). Triggering cleanup.
# 2025-11-12 22:24:17,548 - src.graph_data_source - INFO - Starting memory cleanup (aggressive=False). Initial usage: 5319.7MB
# 2025-11-12 22:24:23,812 - src.graph_data_source - INFO - Memory cleanup completed. Freed 0.0MB. Current usage: 5319.7MB
# 2025-11-12 22:24:24,173 - src.query_processor - INFO - Entity extraction found 6 entities using methods: ['pattern_match', 'pattern_match', 'ner', 'ner', 'ner', 'token_search']
# 2025-11-12 22:24:24,175 - src.query_processor - INFO - Extracted 6 entities
# 2025-11-12 22:24:24,176 - src.query_processor - INFO - Identified relations: ['disease_disease', 'disease_protein', 'protein_protein']
# 2025-11-12 22:24:24,176 - src.retriever - INFO - Starting agent-based retrieval for query: What genes are associated with Alzheimer's disease?
# 2025-11-12 22:24:24,179 - src.retriever - INFO - Using cached retrieval result
# 2025-11-12 22:24:24,181 - src.organizer - INFO - Organizing retrieved context
# 2025-11-12 22:24:24,182 - src.organizer - INFO - Built hierarchical view
# 2025-11-12 22:24:24,597 - src.organizer - INFO - Created 2 pathway clusters
# 2025-11-12 22:24:24,599 - src.organizer - INFO - Created 6 entity groups
# 2025-11-12 22:24:24,607 - src.organizer - INFO - Constructed 128 evidence chains
# 2025-11-12 22:24:25,136 - src.generator - INFO - Generating response
# 2025-11-12 22:24:28,650 - src.generator - INFO - Successfully generated response using LLM API
# Query Type: relationship_query
# Processing Time: 11.12s
#
# Entities Retrieved: 30
# Relationships Retrieved: 50
# Confidence Score: 58.75%
#
# Key Entities (5 of 30):
#   - Alzheimer disease (disease)
#   - secondary interstitial lung disease specific to childhood associated with a granulomatous disease (disease)
#   - TP53 Regulates Metabolic Genes (pathway)
#   - polyneuropathy associated with IgM monoclonal gammapathy with anti-MAG (disease)
#   - Deregulated CDK5 triggers multiple neurodegenerative pathways in Alzheimer's disease models (disease)
#
# Key Relationships (5 of 50):
#   - Deregulated CDK5 triggers multiple neurodegenerative pathways in Alzheimer's disease models --[pathway_pathway]--> Neurodegenerative Diseases
#   - Deregulated CDK5 triggers multiple neurodegenerative pathways in Alzheimer's disease models --[pathway_protein]--> APP
#   - Dementia --[disease_phenotype_positive]--> Alzheimer disease
#   - Neurodegenerative Diseases --[pathway_pathway]--> Deregulated CDK5 triggers multiple neurodegenerative pathways in Alzheimer's disease models
#   - APOE --[protein_protein]--> PSEN1
#
# ================================================================================
# ANSWER:
# ================================================================================
# Certainly, let me provide a detailed explanation of the genes associated with Alzheimer's disease based on the information in the knowledge graph.
#
# Alzheimer's disease is a complex neurodegenerative disorder that affects memory, cognition, and behavior. The knowledge graph highlights several key genes that have been linked to the development and progression of Alzheimer's disease:
#
# 1. APOE (Apolipoprotein E): This gene plays a crucial role in the transport and metabolism of cholesterol in the brain. Certain variants of the APOE gene, particularly the APOE ε4 allele, have been strongly associated with an increased risk of developing late-onset Alzheimer's disease. The knowledge graph shows a direct relationship between the APOE gene and Alzheimer's disease.
#
# 2. APP (Amyloid Precursor Protein): The APP gene encodes a protein that is the precursor to the amyloid-beta (Aβ) peptide, which is a hallmark of Alzheimer's disease. Mutations in the APP gene can lead to the overproduction or altered processing of Aβ, contributing to the formation of amyloid plaques in the brain. The knowledge graph demonstrates the connection between the APP gene and Alzheimer's disease.
#
# 3. PSEN1 (Presenilin 1): Mutations in the PSEN1 gene are associated with early-onset familial Alzheimer's disease. Presenilin 1 is a key component of the gamma-secretase complex, which is responsible for the cleavage of the APP protein, leading to the production of Aβ peptides. The knowledge graph shows the relationship between the PSEN1 gene and Alzheimer's disease.
#
# These genes, along with other genetic and environmental factors, play a crucial role in the development and progression of Alzheimer's disease. The knowledge graph provides a comprehensive overview of the key genes and their associations with this neurodegenerative disorder, highlighting the complex biological mechanisms involved in the pathogenesis of Alzheimer's
# ================================================================================

# %% [markdown]
# ## Custom Query Interface
#
# Enter your own biomedical question below:

# %%
# Custom query - modify the question below
custom_question = "What is the role of BRCA1 in breast cancer development?"

# Process custom query
custom_result = process_query(custom_question)
# Out:
# ================================================================================
# Query: What is the role of BRCA1 in breast cancer development?
# ================================================================================
#
# 2025-11-12 22:24:28,678 - src.query_processor - INFO - Processing query: What is the role of BRCA1 in breast cancer development?
# 2025-11-12 22:24:28,680 - src.query_processor - INFO - Identified query type: general_query
# 2025-11-12 22:24:28,944 - src.graph_data_source - WARNING - Type filtering removed ALL 84 entities. Requested types: ['MolecularFunction']. Attempting type re-inference...
# 2025-11-12 22:24:29,280 - src.graph_data_source - INFO - Type re-inference successful: Re-classified 30 entities, found 30 matches
# 2025-11-12 22:24:29,282 - src.query_processor - INFO - Entity extraction found 5 entities using methods: ['pattern_match', 'pattern_match', 'pattern_match', 'ner', 'token_search']
# 2025-11-12 22:24:29,283 - src.query_processor - INFO - Extracted 5 entities
# 2025-11-12 22:24:29,284 - src.query_processor - INFO - Identified relations: ['disease_protein', 'protein_protein']
# 2025-11-12 22:24:29,285 - src.retriever - INFO - Starting agent-based retrieval for query: What is the role of BRCA1 in breast cancer development?
# 2025-11-12 22:24:31,255 - src.retriever - INFO - Query analysis: {'query_type': 'gene_disease', 'primary_entities': ['BRCA1', 'breast cancer'], 'relevant_relationships': ['associated_with', 'involved_in', 'contributes_to'], 'retrieval_strategy': 'exploration', 'reasoning': "This query is asking about the role of the BRCA1 gene in the development of breast cancer, which is a gene-disease relationship question. The primary entities that need to be explored are the BRCA1 gene and breast cancer. The relevant relationships are likely 'associated_with', 'involved_in', and 'contributes_to', as we need to understand how the BRCA1 gene is linked to and involved in the development of breast cancer. An exploration-based retrieval strategy would be appropriate, where we can search for information on the functions and roles of the BRCA1 gene, as well as its connections to breast cancer pathogenesis and development."}
# 2025-11-12 22:24:31,257 - src.query_processor - INFO - Processing query: What is the role of BRCA1 in breast cancer development?
# 2025-11-12 22:24:31,258 - src.query_processor - INFO - Identified query type: general_query
# 2025-11-12 22:24:31,274 - src.query_processor - INFO - Entity extraction found 5 entities using methods: ['pattern_match', 'pattern_match', 'pattern_match', 'ner', 'token_search']
# 2025-11-12 22:24:31,275 - src.query_processor - INFO - Extracted 5 entities
# 2025-11-12 22:24:31,276 - src.query_processor - INFO - Identified relations: ['disease_protein', 'protein_protein']
# 2025-11-12 22:24:31,342 - src.retriever - INFO - Found seed entity via pattern matching: breast -> breast...
# 2025-11-12 22:24:31,343 - src.retriever - INFO - Identified 6 seed entities
# 2025-11-12 22:24:31,346 - src.retriever - INFO - Added seed entity: Merkel cell skin cancer (type: disease)
# 2025-11-12 22:24:31,352 - src.retriever - INFO - Added seed entity: breast cancer (type: disease)
# 2025-11-12 22:24:31,358 - src.retriever - INFO - Added seed entity: BRCA1 (type: gene)
# 2025-11-12 22:24:31,360 - src.retriever - INFO - Added seed entity: 46,XX disorder of gonadal development (type: disease)
# 2025-11-12 22:24:31,377 - src.retriever - INFO - Added seed entity: Role of ABL in ROBO-SLIT signaling (type: MolecularFunction)
# 2025-11-12 22:24:31,399 - src.retriever - INFO - Added seed entity: breast (type: protein)
# 2025-11-12 22:24:31,406 - src.retriever - INFO - Exploring entity: breast carcinoma
# 2025-11-12 22:24:31,413 - src.retriever - INFO - Added relevant entity: breast carcinoma (type: disease, score: 1.00)
# 2025-11-12 22:24:31,415 - src.retriever - INFO - Exploring entity: male breast
# 2025-11-12 22:24:31,442 - src.retriever - INFO - Added relevant entity: male breast (type: protein, score: 1.00)
# 2025-11-12 22:24:31,445 - src.retriever - INFO - Batch analyzing 1 borderline entities
# 2025-11-12 22:24:31,450 - src.retriever - WARNING - Batch analysis failed, falling back to sequential: Cannot run the event loop while another loop is running
# 2025-11-12 22:24:31,451 - src.retriever - INFO - Exploring entity: Neoplasm of the skin
# 2025-11-12 22:24:31,453 - src.retriever - INFO - Using LLM for borderline entity: Neoplasm of the skin
# 2025-11-12 22:24:33,167 - src.retriever - INFO - Exploring entity: DAW1
# 2025-11-12 22:24:33,207 - src.retriever - INFO - Exploring entity: FAM83F
# 2025-11-12 22:24:33,254 - src.retriever - INFO - Exploring entity: MIR146A
# 2025-11-12 22:24:33,308 - src.retriever - INFO - Exploring entity: HIC1
# 2025-11-12 22:24:33,356 - src.retriever - INFO - Exploring entity: NOTCH4
# 2025-11-12 22:24:33,403 - src.retriever - INFO - Exploring entity: PURG
# 2025-11-12 22:24:33,451 - src.retriever - INFO - Exploring entity: CAT
# 2025-11-12 22:24:33,513 - src.retriever - INFO - Exploring entity: MAP3K13
# 2025-11-12 22:24:33,759 - src.retriever - INFO - Method 3.5: Checking for relationships with 1 expected targets: ['BRCA1']
# 2025-11-12 22:24:33,760 - src.retriever - INFO - Agent-based retrieval completed. Retrieved 30 entities, 50 relationships
# 2025-11-12 22:24:33,762 - src.organizer - INFO - Organizing retrieved context
# 2025-11-12 22:24:33,763 - src.organizer - INFO - Built hierarchical view
# 2025-11-12 22:24:34,276 - src.organizer - INFO - Created 0 pathway clusters
# 2025-11-12 22:24:34,278 - src.organizer - INFO - Created 5 entity groups
# 2025-11-12 22:24:34,285 - src.organizer - INFO - Constructed 66 evidence chains
# 2025-11-12 22:24:34,699 - src.generator - INFO - Generating response
# 2025-11-12 22:24:37,317 - src.generator - INFO - Successfully generated response using LLM API
# Query Type: general_query
# Processing Time: 8.64s
#
# Entities Retrieved: 30
# Relationships Retrieved: 50
# Confidence Score: 58.64%
#
# Key Entities (5 of 30):
#   - Merkel cell skin cancer (disease)
#   - breast cancer (disease)
#   - BRCA1 (gene)
#   - 46,XX disorder of gonadal development (disease)
#   - Role of ABL in ROBO-SLIT signaling (MolecularFunction)
#
# Key Relationships (5 of 50):
#   - breast cancer --[disease_disease]--> breast carcinoma
#   - breast cancer --[disease_protein]--> BRCA1
#   - BRCA1 --[disease_protein]--> breast cancer
#   - breast --[anatomy_anatomy]--> male breast
#   - breast carcinoma --[disease_protein]--> BRCA1
#
# ================================================================================
# ANSWER:
# ================================================================================
# Here is a detailed explanation of the role of BRCA1 in breast cancer development:
#
# BRCA1 (Breast Cancer 1) is a critical gene that plays a central role in the development of breast cancer. The knowledge graph shows a strong relationship between BRCA1 and breast cancer - BRCA1 is directly linked to the "breast cancer" disease entity, indicating its importance in this condition.
#
# BRCA1 is a tumor suppressor gene, meaning it normally functions to prevent uncontrolled cell growth and division that can lead to cancer. The protein produced by the BRCA1 gene is involved in several key cellular processes that maintain genomic stability, including DNA damage repair, cell cycle regulation, and transcriptional regulation. When BRCA1 is mutated or dysfunctional, these critical tumor-suppressing activities are disrupted, allowing abnormal cell growth and the development of breast cancer.
#
# Specifically, the knowledge graph shows that BRCA1 interacts with other proteins like MED23, forming complexes that regulate gene expression. Mutations in BRCA1 disrupt these regulatory pathways, leading to dysregulation of genes involved in cell proliferation and survival. This genetic instability ultimately manifests as breast cancer. Understanding the central role of BRCA1 in these biological mechanisms is crucial for developing targeted therapies and improving prevention and early detection of breast cancer.
# ================================================================================

# %% [markdown]
# ## Advanced Usage: Accessing Detailed Results
#
# The `GraphRAGResult` object contains detailed information about the query processing:

# %%
# Access detailed result information
def display_detailed_results(result):
    """Display comprehensive information about query results."""
    print("\n" + "="*80)
    print("DETAILED QUERY RESULTS")
    print("="*80)
    
    print(f"\nQuery Information:")
    print(f"  - Query: {result.query}")
    print(f"  - Query Type: {result.processed_query.query_type}")
    print(f"  - Processing Time: {result.processing_time:.2f}s")
    print(f"  - Confidence: {result.overall_confidence:.2%}")
    
    print(f"\nRetrieval Statistics:")
    print(f"  - Entities Retrieved: {len(result.retrieval_result.entities)}")
    print(f"  - Relationships Retrieved: {len(result.retrieval_result.relationships)}")
    print(f"  - Paths Retrieved: {len(result.retrieval_result.paths)}")
    
    if result.retrieval_result.entities:
        print(f"\nRetrieved Entities:")
        for i, entity in enumerate(result.retrieval_result.entities[:10], 1):
            print(f"  {i}. {entity.name} (Type: {entity.entity_type}, Score: {entity.relevance_score:.3f})")
        if len(result.retrieval_result.entities) > 10:
            print(f"  ... and {len(result.retrieval_result.entities) - 10} more entities")
    
    if result.retrieval_result.relationships:
        print(f"\nRetrieved Relationships:")
        for i, rel in enumerate(result.retrieval_result.relationships[:10], 1):
            print(f"  {i}. {rel.source_entity.name} --[{rel.relation_type}]--> {rel.target_entity.name}")
            print(f"      (Relevance: {rel.relevance_score:.3f})")
        if len(result.retrieval_result.relationships) > 10:
            print(f"  ... and {len(result.retrieval_result.relationships) - 10} more relationships")
    
    print(f"\nGenerated Response:")
    print(f"  - Answer: {result.generated_response.text[:200]}..." if len(result.generated_response.text) > 200 else f"  - Answer: {result.generated_response.text}")
    print(f"  - Response Confidence: {result.generated_response.confidence:.2%}")
    
    print(f"\nMetadata:")
    for key, value in result.metadata.items():
        if isinstance(value, (str, int, float, bool)):
            print(f"  - {key}: {value}")
    
    print("\n" + "="*80)

# Display detailed results for the last query
if 'custom_result' in locals():
    display_detailed_results(custom_result)
# Out:
# ================================================================================
# DETAILED QUERY RESULTS
# ================================================================================
#
# Query Information:
#   - Query: What is the role of BRCA1 in breast cancer development?
#   - Query Type: general_query
#   - Processing Time: 8.64s
#   - Confidence: 58.64%
#
# Retrieval Statistics:
#   - Entities Retrieved: 30
#   - Relationships Retrieved: 50
#   - Paths Retrieved: 29
#
# Retrieved Entities:
#   1. Merkel cell skin cancer (Type: disease, Score: 0.950)
#   2. breast cancer (Type: disease, Score: 0.950)
#   3. BRCA1 (Type: gene, Score: 0.950)
#   4. 46,XX disorder of gonadal development (Type: disease, Score: 0.950)
#   5. Role of ABL in ROBO-SLIT signaling (Type: MolecularFunction, Score: 0.950)
#   6. breast (Type: protein, Score: 0.950)
#   7. breast carcinoma (Type: disease, Score: 1.000)
#   8. male breast (Type: protein, Score: 1.000)
#   9. APUdoma (Type: protein, Score: 0.600)
#   10. Neoplasm of the skin (Type: protein, Score: 0.500)
#   ... and 20 more entities
#
# Retrieved Relationships:
#   1. breast cancer --[disease_disease]--> breast carcinoma
#       (Relevance: 0.700)
#   2. breast cancer --[disease_protein]--> BRCA1
#       (Relevance: 0.700)
#   3. BRCA1 --[disease_protein]--> breast cancer
#       (Relevance: 0.700)
#   4. breast --[anatomy_anatomy]--> male breast
#       (Relevance: 0.700)
#   5. breast carcinoma --[disease_protein]--> BRCA1
#       (Relevance: 0.700)
#   6. breast carcinoma --[disease_disease]--> breast cancer
#       (Relevance: 0.700)
#   7. male breast --[anatomy_anatomy]--> breast
#       (Relevance: 0.700)
#   8. Merkel cell skin cancer --[phenotype_phenotype]--> APUdoma
#       (Relevance: 0.600)
#   9. Merkel cell skin cancer --[phenotype_phenotype]--> Neoplasm of the skin
#       (Relevance: 0.500)
#   10. breast cancer --[disease_protein]--> MED28
#       (Relevance: 0.800)
#   ... and 40 more relationships
#
# Generated Response:
#   - Answer: Here is a detailed explanation of the role of BRCA1 in breast cancer development:
#
# BRCA1 (Breast Cancer 1) is a critical gene that plays a central role in the development of breast cancer. The knowled...
#   - Response Confidence: 52.14%
#
# Metadata:
#   - query_id: 4
#   - timestamp: 1763007877.3193338
#
# ================================================================================

# %% [markdown]
# ## System Performance Metrics
#
# Monitor system performance and statistics:

# %%
# Display system performance metrics
print("System Performance Metrics:")
print(f"  - Total Queries Processed: {graphrag.query_count}")
print(f"  - Total Processing Time: {graphrag.total_processing_time:.2f}s")
if graphrag.query_count > 0:
    print(f"  - Average Query Time: {graphrag.total_processing_time / graphrag.query_count:.2f}s")
print(f"  - Error Count: {graphrag.error_count}")
print(f"  - Success Rate: {(1 - graphrag.error_count / max(graphrag.query_count, 1)) * 100:.1f}%")
# Out:
# System Performance Metrics:
#   - Total Queries Processed: 4
#   - Total Processing Time: 80.91s
#   - Average Query Time: 20.23s
#   - Error Count: 0
#   - Success Rate: 100.0%

# %% [markdown]
# ## Notes
#
# - **First-time initialization**: Loading PrimeKG data may take several minutes. Subsequent runs use cached data for faster startup.
# - **Query types**: The system automatically identifies query intent (treatment, mechanism, side effects, relationships, pathways).
# - **Multi-hop reasoning**: The system performs multi-hop graph traversal to find complex relationships (e.g., Drug → Disease → Phenotype for side effects).
# - **Edge Handling**: The system includes comprehensive error handling and fallback mechanisms to ensure reliable operation.
#
# ## References
#
# - PrimeKG: A knowledge graph for precision medicine (doi:10.7910/DVN/IXA7BM)
# - GraphRAG Framework: arXiv:2501.00309
